# %% [markdown]
# <font color="Teal" face="Comic Sans MS,arial"><font color = 'darkblue'>
#   <h1 align="center"><i>Análisis de acciones tecnológicas.</i></h1>
#   </font>
#   <font color="Black" face="Comic Sans MS,arial">
#     <h5 align="center"><i>Integrante: **Avalos Gonzalez Joel Sebastian**</i></h5>
#     <h5 align="center"><i>Integrante: **Barriga Rosales Alan**</i></h5>
#     <h5 align="center"><i>Integrante: **Hernández Lozano Juan Pablo**</i></h5>
#     <h5 align="center"><i>Materia: Mineria de datos</i></h5>
#   </font>

# %% [markdown]
# # Esquema de la semana 1 (01/11/2021--05/11/2021)
# - [Prework(Carga de datos)](#1)
#     - [Marco teorico e introduccion](#01)
#     - [Objetivo y alcance del modelo](#02)
#     - [Marco estrategico y definiciones](#03)
#     - [Analisis exploratorio de los datos](#04)
#
# - [Desarrollo e integacion de la informacion](#2)
#     - [Tratamiento e integracion de los datos](#05)
#     - [Limpieza de la informacion](#06)

# %% [markdown]
# <a name='1'> </a>
# ## Prework(Carga de datos)

# %% [markdown]
# <a name='01'> </a>
# ### Marco teorico e introduccion

# %% [markdown]
# Existen diferentes empresas de tecnología multinacional estadounidense que se especializan en la venta de productos y servicios relacionados con el internet, que incluyen tecnologías de publicidad en línea, un motor de búsqueda, computacional en la nube, software y hardware, entre otras características a las cuales se especializan las distintas empresas, nos centraremos en $6$ empresas más retribuidas en este sector, las cuales son: Google, Amazon, Facebook, Apple, Microsoft, Netflix. Las cuales día con día se compran y venden acciones, esto es muy importante para un inversionista, ya que saber en qué momento entrar al mercado puede ser una cuestión complicada, vender acciones o comprar acciones.

# %% [markdown]
# <a name='02'> </a>
# ### Objetivo y alcance del modelo

# %% [markdown]
# El objetivo de nuestro modelo es:
# - Comparar, relacionar las distintas empresas para predecir el comportamiento de ellas mismas y tomar decisiones de inversion a corto plazo.
#
# El alcance de nuestro modelo es:
#
# - La predicción del precio de cierre de una acción con un margen de volatilidad y precisión.

# %% [markdown]
# <a name='03'> </a>
# ### Marco estrategico y definiciones

# %% [markdown]
# **Posibles criterios de satisfacción para el negocio.**
#
# -  Disminución de incertidumbre en inversión.
#
# -  Mayor diversificación en el portafolio de inversión.
#
# -  Optimizar tiempos en toma de decisones.
#
# **Ideas de solución**
#
# -  Análisis de series de tiempo y/o modelos de ML
#
# -  Relación entre empresas con alta expectativa de inversión
#
# -  Apoyo en resultados de los análisis para toma de decisiones

# %% [markdown]
# <a name='04'> </a>
# ### Analisis exploratorio de los datos

# %% [markdown]
# ##### Instalacion de paquetes

# %%
pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 13.5 MB/s
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
#Using yfinance to access Yahoo Historical Stocks
import yfinance as yf
from __future__ import division
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

#Visualisation imports
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from datetime import datetime

# %%
stock_list = ['AAPL','GOOG','MSFT','AMZN','FB','NFLX', 'TSLA']

end = datetime.now()

#Start date set to 1 year back
start = datetime(end.year-1,end.month,end.day) 

for stock in stock_list:
    globals()[stock] = yf.download(stock,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
AAPL.head()
# Out:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2020-12-02  122.019997  123.370003  ...  122.325890  89004200
# 2020-12-03  123.519997  123.779999  ...  122.186752  78967600
# 2020-12-04  122.599998  122.860001  ...  121.500977  78260400
# 2020-12-07  122.309998  124.570000  ...  122.991783  86712000
# 2020-12-08  124.370003  124.980003  ...  123.617920  82225500
#
# [5 rows x 6 columns]

# %% [markdown]
# De cada empresa tenemos la fecha, el precio en que abre, el precio más alto que alcanzó en el día, el mínimo precio alcanzado en el día, el precio de cierre al día, el precio de cierre ajustado y el volumen del mercado.

# %%
NFLX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 253 entries, 2020-12-02 to 2021-12-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       253 non-null    float64
#  1   High       253 non-null    float64
#  2   Low        253 non-null    float64
#  3   Close      253 non-null    float64
#  4   Adj Close  253 non-null    float64
#  5   Volume     253 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %% [markdown]
# ##### Cambio en el precio de las acciones a lo largo del tiempo (1 año)

# %%
import plotly.graph_objects as go
fig = go.Figure()

#fig = px.line(x=NFLX.index, y=NFLX['Adj Close'], title='Time Series with Range Slider and Selectors')
fig.add_trace(go.Scatter(x=FB.index, y=FB['Adj Close'], name = 'FB', line_color = 'blue'))

fig.add_trace(go.Scatter(x=NFLX.index, y=NFLX['Adj Close'], name = 'NFLX', line_color = 'red'))
fig.add_trace(go.Scatter(x=AAPL.index, y=AAPL['Adj Close'], name = 'AAPL', line_color = 'gray'))
fig.add_trace(go.Scatter(x=GOOG.index, y=GOOG['Adj Close'], name = 'GOOG', line_color = 'green'))
fig.add_trace(go.Scatter(x=TSLA.index, y=TSLA['Adj Close'], name = 'TSLA', line_color = 'black'))
fig.add_trace(go.Scatter(x=AMZN.index, y=AMZN['Adj Close'], name = 'AMZN', line_color = 'orange'))
fig.add_trace(go.Scatter(x=MSFT.index, y=MSFT['Adj Close'], name = 'MSFT', line_color = 'pink'))

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de cierre de las empresas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c19b1f54-bb91-437d-b6e1-8bfdfdb53f79" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c19b1f54-bb91-437d-b6e1-8bfdfdb53f79")) {
#                     Plotly.newPlot(
#                         'c19b1f54-bb91-437d-b6e1-8bfdfdb53f79',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

#fig = px.line(x=NFLX.index, y=NFLX['Adj Close'], title='Time Series with Range Slider and Selectors')
fig.add_trace(go.Scatter(x=FB.index, y=FB['Volume'], name = 'FB', line_color = 'blue'))
fig.add_trace(go.Scatter(x=NFLX.index, y=NFLX['Volume'], name = 'NFLX', line_color = 'red'))
fig.add_trace(go.Scatter(x=AAPL.index, y=AAPL['Volume'], name = 'AAPL', line_color = 'gray'))
fig.add_trace(go.Scatter(x=GOOG.index, y=GOOG['Volume'], name = 'GOOG', line_color = 'green'))
fig.add_trace(go.Scatter(x=TSLA.index, y=TSLA['Volume'], name = 'TSLA', line_color = 'black'))
fig.add_trace(go.Scatter(x=AMZN.index, y=AMZN['Volume'], name = 'AMZN', line_color = 'orange'))
fig.add_trace(go.Scatter(x=MSFT.index, y=MSFT['Adj Close'], name = 'MSFT', line_color = 'pink'))

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo del volumen de las empresas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1b5d3652-2470-4b02-9807-eb032530861d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b5d3652-2470-4b02-9807-eb032530861d")) {
#                     Plotly.newPlot(
#                         '1b5d3652-2470-4b02-9807-eb032530861d',
# ...

# %% [markdown]
# ######  Calcular promedios móviles

# %%
averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    NFLX[label] = NFLX['Adj Close'].rolling(window = avg, center = False).mean()

averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    AAPL[label] = AAPL['Adj Close'].rolling(window = avg, center = False).mean()

averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    GOOG[label] = GOOG['Adj Close'].rolling(window = avg, center = False).mean()


averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    TSLA[label] = TSLA['Adj Close'].rolling(window = avg, center = False).mean()


averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    AMZN[label] = AMZN['Adj Close'].rolling(window = avg, center = False).mean()

averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    FB[label] = FB['Adj Close'].rolling(window = avg, center = False).mean()

# %%
averages = [10,25,50]
for avg in averages:
    label = "MAvg for %s days" %(str(avg))
    MSFT[label] = MSFT['Adj Close'].rolling(window = avg, center = False).mean()

# %%
NFLX.tail()
# Out:
#                   Open        High  ...  MAvg for 25 days  MAvg for 50 days
# Date                                ...
# 2021-11-26  675.000000  676.409973  ...        669.780398        641.972797
# 2021-11-29  663.200012  667.989990  ...        669.742798        643.462598
# 2021-11-30  668.200012  675.380005  ...        668.552400        644.791998
# 2021-12-01  649.479980  654.520020  ...        666.522400        645.684598
# 2021-12-02  617.099976  625.359985  ...        664.606001        646.171798
#
# [5 rows x 9 columns]

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=NFLX.index, y=NFLX['Adj Close'], name = 'NFLX', line_color = 'blue'))
fig.add_trace(go.Scatter(x=NFLX.index, y=NFLX['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=NFLX.index, y=NFLX['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=NFLX.index, y=NFLX['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Netflix')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4ae39166-df3c-42fc-8805-e29e73670acc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ae39166-df3c-42fc-8805-e29e73670acc")) {
#                     Plotly.newPlot(
#                         '4ae39166-df3c-42fc-8805-e29e73670acc',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=AAPL.index, y=AAPL['Adj Close'], name = 'APPL', line_color = 'blue'))
fig.add_trace(go.Scatter(x=AAPL.index, y=AAPL['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=AAPL.index, y=AAPL['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=AAPL.index, y=AAPL['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Apple')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ac40dddc-747d-4014-b23d-6b62ebc0c39f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ac40dddc-747d-4014-b23d-6b62ebc0c39f")) {
#                     Plotly.newPlot(
#                         'ac40dddc-747d-4014-b23d-6b62ebc0c39f',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=GOOG.index, y=GOOG['Adj Close'], name = 'GOOG', line_color = 'blue'))
fig.add_trace(go.Scatter(x=GOOG.index, y=GOOG['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=GOOG.index, y=GOOG['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=GOOG.index, y=GOOG['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Google')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="60225d17-3070-4635-ae13-6a8aee91ea2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60225d17-3070-4635-ae13-6a8aee91ea2e")) {
#                     Plotly.newPlot(
#                         '60225d17-3070-4635-ae13-6a8aee91ea2e',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=TSLA.index, y=TSLA['Adj Close'], name = 'TSLA', line_color = 'blue'))
fig.add_trace(go.Scatter(x=TSLA.index, y=TSLA['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=TSLA.index, y=TSLA['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=TSLA.index, y=TSLA['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Tesla')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="db449abf-2389-4995-96d6-919a4673e18a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db449abf-2389-4995-96d6-919a4673e18a")) {
#                     Plotly.newPlot(
#                         'db449abf-2389-4995-96d6-919a4673e18a',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=AMZN.index, y=AMZN['Adj Close'], name = 'AMZN', line_color = 'blue'))
fig.add_trace(go.Scatter(x=AMZN.index, y=AMZN['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=AMZN.index, y=AMZN['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=AMZN.index, y=AMZN['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Amazon')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="24d7900d-0de3-4dc9-8ea5-65acaf3bb73a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("24d7900d-0de3-4dc9-8ea5-65acaf3bb73a")) {
#                     Plotly.newPlot(
#                         '24d7900d-0de3-4dc9-8ea5-65acaf3bb73a',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=FB.index, y=FB['Adj Close'], name = 'FB', line_color = 'blue'))
fig.add_trace(go.Scatter(x=FB.index, y=FB['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=FB.index, y=FB['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=FB.index, y=FB['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Facebook')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3ae3d33d-63ad-4852-8d9a-3c300bd86c56" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3ae3d33d-63ad-4852-8d9a-3c300bd86c56")) {
#                     Plotly.newPlot(
#                         '3ae3d33d-63ad-4852-8d9a-3c300bd86c56',
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()

fig.add_trace(go.Scatter(x=MSFT.index, y=MSFT['Adj Close'], name = 'MSFT', line_color = 'blue'))
fig.add_trace(go.Scatter(x=MSFT.index, y=MSFT['MAvg for 10 days'], name = 'MAvg for 10 days', line_color = 'red'))
fig.add_trace(go.Scatter(x=MSFT.index, y=MSFT['MAvg for 25 days'], name = 'MAvg for 25 days', line_color = 'orange'))
fig.add_trace(go.Scatter(x=MSFT.index, y=MSFT['MAvg for 50 days'], name = 'MAvg for 50 days', line_color = 'green'))
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.update_layout(title='Serie de tiempo de la empresa Microsoft')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2fe65349-7f3b-4680-b45a-a21ebb30ddbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fe65349-7f3b-4680-b45a-a21ebb30ddbc")) {
#                     Plotly.newPlot(
#                         '2fe65349-7f3b-4680-b45a-a21ebb30ddbc',
# ...

# %% [markdown]
# ###### Correlación entre diferentes rendimientos diarios de acciones
#
# Ahora examinemos la tendencia entre algunos pares de acciones, utilizando el cambio porcentual de los rendimientos diarios.

# %%
close_compr = yf.download(stock_list,start,end)['Adj Close']
rets_compr = close_compr.pct_change()
rets_compr.tail()
# Out:
# [*********************100%***********************]  7 of 7 completed
#                 AAPL      AMZN        FB  ...      MSFT      NFLX      TSLA
# Date                                      ...
# 2021-11-26 -0.031678 -0.021185 -0.023280  ... -0.024356  0.011165 -0.030538
# 2021-11-29  0.021874  0.016267  0.014739  ...  0.021081 -0.002704  0.050900
# 2021-11-30  0.031578 -0.015302 -0.040144  ... -0.017943 -0.033050  0.006834
# 2021-12-01 -0.003206 -0.018064 -0.042717  ... -0.001543 -0.037592 -0.043468
# 2021-12-02 -0.006130 -0.001847 -0.000676  ... -0.001787 -0.002104 -0.009498
#
# [5 rows x 7 columns]

# %%
import plotly.express as px
fig = px.scatter(rets_compr, x="NFLX", y="AAPL", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="adee0d45-3d39-46ff-97dc-57c7305e3d7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("adee0d45-3d39-46ff-97dc-57c7305e3d7d")) {
#                     Plotly.newPlot(
#                         'adee0d45-3d39-46ff-97dc-57c7305e3d7d',
# ...

# %% [markdown]
# Parece haber una correlación moderada entre los retornos de Netflix y Apple.
#
# Generaré todos los gráficos por pares para ver si hay correlaciones más fuertes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(rets_compr.dropna())

# %% [markdown]
# ###### Correlacion entre las empresas

# %%
data = {'NFLX':NFLX['Open'],'AAPL':AAPL['Open'], 'AMZN':AMZN['Open'], 'GOOG':GOOG['Open'], 'FB':FB['Open'], 'MSFT':MSFT['Open'], 'TSLA':TSLA['Open'] }
actCorr = pd.DataFrame(data)
actCorr.head()
# Out:
#                   NFLX        AAPL  ...        MSFT        TSLA
# Date                                ...
# 2020-12-02  501.619995  122.019997  ...  214.880005  556.440002
# 2020-12-03  502.989990  123.519997  ...  214.610001  590.020020
# 2020-12-04  497.500000  122.599998  ...  214.220001  591.010010
# 2020-12-07  500.010010  122.309998  ...  214.369995  604.919983
# 2020-12-08  517.900024  124.370003  ...  213.970001  625.510010
#
# [5 rows x 7 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(actCorr.corr(), annot=True, linewidths=.5, cbar=False)
plt.show()

# %% [markdown]
# <a name='2'> </a>
# ## Desarrollo e integacion de la informacion

# %% [markdown]
# <a name='05'> </a>
# ### Tratamiento e integracion de los datos

# %% [markdown]
# Para el objetivo de nuestro proyecto tomaremos una temporalidad de corto plazo, los ultimos $15$ dias en los que ocurrieron cambios en las empresas hora por hora, esto porque.....

# %% [markdown]
# <a name='06'> </a>
# ### Limpieza de la informacion

# %% [markdown]
# **Nota:** Para cada una de las empresas seleccionadas tendremos el tipo de datos al cual pertenece cada variable y tambien vemos que no tenemos alguna variable nula, por lo cual podemos concluir que nuestra informacion esta limpia.
#
# Pero al hacer mas pequena la temporalidad tendremos datos mas reducidos de cada empresa, estos son:

# %%
stock_list = ['AAPL','GOOG','MSFT','AMZN','FB','NFLX', 'TSLA']

for stock in stock_list:
    globals()[stock] = yf.download(stock,period="15d", interval="1h")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
print(len(AAPL))
print(len(GOOG))
print(len(MSFT))
print(len(AMZN))
print(len(FB))
print(len(NFLX))
print(len(TSLA))
# Out:
# 102
# 102
# 102
# 102
# 102
# 102
# 102

# %% [markdown]
# ##### Ejemplo de la empresa AAPL

# %%
AAPL
# Out:
#                                  Open        High  ...   Adj Close    Volume
# 2021-11-11 09:30:00-05:00  148.679993  149.429993  ...  148.429993  10544554
# 2021-11-11 10:30:00-05:00  148.429993  148.660004  ...  148.320007   5133531
# 2021-11-11 11:30:00-05:00  148.328995  148.570007  ...  148.020004   4736907
# 2021-11-11 12:30:00-05:00  148.020004  148.119995  ...  147.789993   3846912
# 2021-11-11 13:30:00-05:00  147.779999  148.080002  ...  147.934998   3670262
# ...                               ...         ...  ...         ...       ...
# 2021-12-02 11:30:00-05:00  161.970001  163.699997  ...  163.429993  16610759
# 2021-12-02 12:30:00-05:00  163.425003  163.649994  ...  162.839996  13527840
# 2021-12-02 13:30:00-05:00  162.850006  163.979996  ...  163.779999  11503150
# 2021-12-02 14:30:00-05:00  163.770004  163.969894  ...  163.460007  10432352
# 2021-12-02 15:30:00-05:00  163.449997  164.199997  ...  163.789993  10656094
#
# [102 rows x 6 columns]
